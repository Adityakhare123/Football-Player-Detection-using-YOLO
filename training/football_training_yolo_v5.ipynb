# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dN9uJ4ZFbFrsAPZMVmNM")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\GG1\\programs\\Linkites\\Football\\training\\football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1','football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1','football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1','football-players-detection-1/football-players-detection-1/valid')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\a1cho\anaconda3\Lib\shutil.py:886, in move(src, dst, copy_function)
#     885 try:
# --> 886     os.rename(src, real_dst)
#     887 except OSError:
#
# PermissionError: [WinError 5] Access is denied: 'football-players-detection-1' -> 'football-players-detection-1/football-players-detection-1/train\\football-players-detection-1'
#
# During handling of the above exception, another exception occurred:
#
# Error                                     Traceback (most recent call last)
# Cell In[11], line 3
#       1 import shutil
# ----> 3 shutil.move('football-players-detection-1','football-players-detection-1/football-players-detection-1/train')
#       4 shutil.move('football-players-detection-1/test','football-players-detection-1/football-players-detection-1/test')
# ...

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# 'yolo' is not recognized as an internal or external command,
# operable program or batch file.
